# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from csv import writer
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.Data Extraction

# %%
url= requests.get("https://www.jumia.co.ke/smartphones/?shipped_from=country_local#catalog-listing").text
soup=BeautifulSoup(url,'lxml')
item_list = soup.find_all('article',class_="prd _fb col c-prd",)

#item_list

for item in item_list:
    Productname= item.find('h3',class_='name')
    Price = item.find('div',class_='prc')
    print(Productname)
    print(Price)
# Out:
# <h3 class="name">Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,Polar Black</h3>
# <div class="prc">KSh 10,299</div>
# <h3 class="name">Tecno Pop 6 6.1", 2GB RAM+32GB, 8MP, 4G (Dual Sim) 5000MAh -Lime Green</h3>
# <div class="prc">KSh 8,819</div>
# <h3 class="name">XIAOMI Redmi 9A, 6.53", 2GB+32GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Grey</h3>
# <div class="prc">KSh 11,499</div>
# <h3 class="name">Oppo A83 64GB + 4GB RAM - 4G LTE Dual SIM -  5.7-inch,Red</h3>
# <div class="prc">KSh 9,990</div>
# <h3 class="name">XIAOMI Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Graphite Grey</h3>
# <div class="prc">KSh 14,799</div>
# <h3 class="name">XIAOMI Redmi 10C, 6.53'', [4GB RAM + 64GB], 4G, DUAL SIM + 8 FREE GIFTS</h3>
# <div class="prc">KSh 17,499</div>
# <h3 class="name">Infinix Smart 6, 6.6", 32GB + 2GB RAM (Dual SIM), 5000mAh, Quartz Cyan</h3>
# <div class="prc">KSh 10,695</div>
# <h3 class="name">XIAOMI Redmi 10 6.5'' Inches 4+128GB 50MP Rear Camera 4G Smartphone - Grey</h3>
# <div class="prc">KSh 18,799</div>
# <h3 class="name">Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual SIM), 5000mAh, Black</h3>
# <div class="prc">KSh 19,299</div>
# <h3 class="name">Oppo A16k, 6.52", 32GB + 3GB RAM (Dual SIM), 4230mAh - Blue</h3>
# <div class="prc">KSh 14,278</div>
# <h3 class="name">Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dual SIM), 5000mAh, Blue</h3>
# <div class="prc">KSh 21,699</div>
# <h3 class="name">Tecno Pova Neo, 6.8", 64GB+ 4GB (Dual SIM),4G LTE, 6000mAh, Obsidian Black</h3>
# <div class="prc">KSh 15,999</div>
# <h3 class="name">Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue</h3>
# <div class="prc">KSh 19,299</div>
# <h3 class="name">Itel A14 Plus, 4", 8GB + 1GB RAM, 2500mAh - Blue</h3>
# <div class="prc">KSh 4,443</div>
# <h3 class="name">Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dual SIM), 5000mAh, Black</h3>
# <div class="prc">KSh 21,699</div>
# <h3 class="name">Tecno Pop 6 GO, 6", 32GB + 2GB RAM ,(Dual SIM), 4000mAh,  + CLASSIC GIFTS</h3>
# <div class="prc">KSh 9,445</div>
# <h3 class="name">Nokia C1 2nd Edition, 5.45", 1GB +16GB - (DUAL SIM),Android 11, Blue</h3>
# <div class="prc">KSh 7,139</div>
# <h3 class="name">Oppo A83 64GB + 4GB RAM - 4G LTE Dual SIM -  5.7-inch,Black</h3>
# <div class="prc">KSh 9,790</div>
# <h3 class="name">XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2MP Camera, 4G, Dual SIM - Lavender Purple</h3>
# <div class="prc">KSh 16,299</div>
# <h3 class="name">Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000mAh,Dual Sim- (Black) Onyx</h3>
# <div class="prc">KSh 11,699</div>
# <h3 class="name">Samsung Galaxy A23, 6.6″, 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue</h3>
# <div class="prc">KSh 22,499</div>
# <h3 class="name">Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, Eco Black</h3>
# <div class="prc">KSh 22,499</div>
# <h3 class="name">Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, MEMPHIS GREEN</h3>
# <div class="prc">KSh 22,846</div>
# <h3 class="name">Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual SIM), 5000mAh, Black</h3>
# <div class="prc">KSh 15,299</div>
# <h3 class="name">XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2MP Camera, 4G, Dual SIM - Aurora Green</h3>
# <div class="prc">KSh 16,499</div>
# <h3 class="name">Infinix HOT 12i, 6.6''{ 64GB+2GB Expandable To 4GBRAM} (Dual SIM), 4G LTE, 5000mAh,black</h3>
# <div class="prc">KSh 12,995</div>
# <h3 class="name">XIAOMI Redmi 10C 6.71'', 4GB+128GB, 50MP+2MP Camera, 4G, Dual SIM - Blue</h3>
# <div class="prc">KSh 19,099</div>
# <h3 class="name">Samsung Galaxy A03 6.5" 3GB RAM+32GB ROM 48 MP //Dual SIM-Blue+FREE EARBUDS+C+W</h3>
# <div class="prc">KSh 13,990</div>
# <h3 class="name">Tecno Spark 8C 6.6" 64GB+ 2GB RAM Dual Sim, Black + Smart Watch + P.Bank</h3>
# <div class="prc">KSh 13,898</div>
# <h3 class="name">Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, Eco Black</h3>
# <div class="prc">KSh 22,568</div>
# <h3 class="name">XIAOMI Redmi 9A 6.53", 2GB RAM+32GB, 5000mAh, Dual SIM, 4G LTE - Glacial Blue</h3>
# <div class="prc">KSh 11,499</div>
# <h3 class="name">Infinix Smart 6, 6.6", 32GB + 2GB RAM (Dual SIM), 5000mAh +FREE GIFTS</h3>
# <div class="prc">KSh 11,100</div>
# <h3 class="name">Samsung Galaxy A13, 6.6", 128GB + 4GB (Dual SIM), Blue + Smart Watch &amp; Power Bank</h3>
# <div class="prc">KSh 22,997</div>
# <h3 class="name">Itel A33 Plus,,5.0" Screen Display(16GB+1GB),Fingerprint,(Dual Sim) Blue,,w.s"</h3>
# <div class="prc">KSh 6,160</div>
# <h3 class="name">Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM), 5000mAh, Turquoise Cyan</h3>
# <div class="prc">KSh 12,999</div>
# <h3 class="name">Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue</h3>
# <div class="prc">KSh 15,299</div>
# <h3 class="name">Infinix Smart 6, 6.6", 2GB RAM, 32GB, Android 10, XOS 7.6, 5000mAh, 3G - Ocean Wave</h3>
# <div class="prc">KSh 10,695</div>
# <h3 class="name">Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM), 5000mAh, Magnet Black</h3>
# <div class="prc">KSh 12,999</div>
# <h3 class="name">Itel A58 Lite, 6.3", 32GB + 2GB RAM (Dual SIM), 4000mAh, Blue Wave</h3>
# <div class="prc">KSh 8,255</div>
# <h3 class="name">Ulefone Note 6, 6.1", 32GB + 1GB RAM (Dual SIM), 3300mAh, Black</h3>
# <div class="prc">KSh 7,599</div>

# %%
#To remove the html tags
all_items=[]

for item in item_list:
    Productname= item.find('h3',class_='name')
    Price = item.find('div',class_='prc')
    
    print(Productname.text.strip())
    print(Price.text.strip())
    all_items.append((Productname.text.strip(),Price.text.strip()))
# Out:
# Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,Polar Black
# KSh 10,299
# Tecno Pop 6 6.1", 2GB RAM+32GB, 8MP, 4G (Dual Sim) 5000MAh -Lime Green
# KSh 8,819
# XIAOMI Redmi 9A, 6.53", 2GB+32GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Grey
# KSh 11,499
# Oppo A83 64GB + 4GB RAM - 4G LTE Dual SIM -  5.7-inch,Red
# KSh 9,990
# XIAOMI Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Graphite Grey
# KSh 14,799
# XIAOMI Redmi 10C, 6.53'', [4GB RAM + 64GB], 4G, DUAL SIM + 8 FREE GIFTS
# KSh 17,499
# Infinix Smart 6, 6.6", 32GB + 2GB RAM (Dual SIM), 5000mAh, Quartz Cyan
# KSh 10,695
# XIAOMI Redmi 10 6.5'' Inches 4+128GB 50MP Rear Camera 4G Smartphone - Grey
# KSh 18,799
# Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual SIM), 5000mAh, Black
# KSh 19,299
# Oppo A16k, 6.52", 32GB + 3GB RAM (Dual SIM), 4230mAh - Blue
# KSh 14,278
# Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dual SIM), 5000mAh, Blue
# KSh 21,699
# Tecno Pova Neo, 6.8", 64GB+ 4GB (Dual SIM),4G LTE, 6000mAh, Obsidian Black
# KSh 15,999
# Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue
# KSh 19,299
# Itel A14 Plus, 4", 8GB + 1GB RAM, 2500mAh - Blue
# KSh 4,443
# Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dual SIM), 5000mAh, Black
# KSh 21,699
# Tecno Pop 6 GO, 6", 32GB + 2GB RAM ,(Dual SIM), 4000mAh,  + CLASSIC GIFTS
# KSh 9,445
# Nokia C1 2nd Edition, 5.45", 1GB +16GB - (DUAL SIM),Android 11, Blue
# KSh 7,139
# Oppo A83 64GB + 4GB RAM - 4G LTE Dual SIM -  5.7-inch,Black
# KSh 9,790
# XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2MP Camera, 4G, Dual SIM - Lavender Purple
# KSh 16,299
# Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000mAh,Dual Sim- (Black) Onyx
# KSh 11,699
# Samsung Galaxy A23, 6.6″, 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue
# KSh 22,499
# Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, Eco Black
# KSh 22,499
# Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, MEMPHIS GREEN
# KSh 22,846
# Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual SIM), 5000mAh, Black
# KSh 15,299
# XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2MP Camera, 4G, Dual SIM - Aurora Green
# KSh 16,499
# Infinix HOT 12i, 6.6''{ 64GB+2GB Expandable To 4GBRAM} (Dual SIM), 4G LTE, 5000mAh,black
# KSh 12,995
# XIAOMI Redmi 10C 6.71'', 4GB+128GB, 50MP+2MP Camera, 4G, Dual SIM - Blue
# KSh 19,099
# Samsung Galaxy A03 6.5" 3GB RAM+32GB ROM 48 MP //Dual SIM-Blue+FREE EARBUDS+C+W
# KSh 13,990
# Tecno Spark 8C 6.6" 64GB+ 2GB RAM Dual Sim, Black + Smart Watch + P.Bank
# KSh 13,898
# Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (4G LTE) 5000mAh, Eco Black
# KSh 22,568
# XIAOMI Redmi 9A 6.53", 2GB RAM+32GB, 5000mAh, Dual SIM, 4G LTE - Glacial Blue
# KSh 11,499
# Infinix Smart 6, 6.6", 32GB + 2GB RAM (Dual SIM), 5000mAh +FREE GIFTS
# KSh 11,100
# Samsung Galaxy A13, 6.6", 128GB + 4GB (Dual SIM), Blue + Smart Watch & Power Bank
# KSh 22,997
# Itel A33 Plus,,5.0" Screen Display(16GB+1GB),Fingerprint,(Dual Sim) Blue,,w.s"
# KSh 6,160
# Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM), 5000mAh, Turquoise Cyan
# KSh 12,999
# Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual SIM), 5000mAh, Blue
# KSh 15,299
# Infinix Smart 6, 6.6", 2GB RAM, 32GB, Android 10, XOS 7.6, 5000mAh, 3G - Ocean Wave
# KSh 10,695
# Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM), 5000mAh, Magnet Black
# KSh 12,999
# Itel A58 Lite, 6.3", 32GB + 2GB RAM (Dual SIM), 4000mAh, Blue Wave
# KSh 8,255
# Ulefone Note 6, 6.1", 32GB + 1GB RAM (Dual SIM), 3300mAh, Black
# KSh 7,599

# %%
#To put the data in a dataframe
df = pd.DataFrame(all_items)
df.columns = ["name", "price"]
df.to_csv('jumia_dataframe.csv')

# %% [markdown]
# ## 2.Data Assesment

# %%
df=pd.read_excel(r"C:\Users\kibe\Downloads\Book.xlsx")
df.sample(5)
# Out:
#                                               Column1     Column2
# 52  Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (...  KSh 22,499
# 13  Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM...  KSh 12,999
# 50  Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000m...  KSh 11,699
# 42  Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual...  KSh 19,299
# 29  Samsung Galaxy A33 5G, 6.4", 128GB + 6GB RAM (...  KSh 35,599

# %%
df.head()
# Out:
#                                              Column1     Column2
# 0  Itel A58, 6.6",16 GB + 1GB, (Dual SIM) - Starr...   KSh 8,150
# 1  XIAOMI POCO M5 4GB + 128GB 6.58'' IPS LCD 50MP...  KSh 17,999
# 2  Poco M4 Pro 6GB + 128GB 64MP 5000mAh 4G NFC Sm...  KSh 25,799
# 3  Oppo A55, 6.51", 128GB + 4GB RAM (Dual SIM), 5...  KSh 23,999
# 4  XIAOMI Redmi 10 6.5'' Inches 4+64GB 50MP Rear ...  KSh 19,999

# %%
df.tail()
# Out:
#                                                  name       price
# 35  Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual...  KSh 15,299
# 36  Infinix Smart 6, 6.6", 2GB RAM, 32GB, Android ...  KSh 10,695
# 37  Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM...  KSh 12,999
# 38  Itel A58 Lite, 6.3", 32GB + 2GB RAM (Dual SIM)...   KSh 8,255
# 39  Ulefone Note 6, 6.1", 32GB + 1GB RAM (Dual SIM...   KSh 7,599

# %%
df.isna().sum()
# Out:
# Column1    0
# Column2    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  60 non-null     object
#  1   Column2  60 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns = {'Column1':'name'}, inplace = True)
df.rename(columns = {'Column2':'price'}, inplace = True)

# %% [markdown]
# ## 3.Data Cleaning

# %% [markdown]
# 1.To remove the 'ksh'symbol in the price column and to change the datatype to integer

# %%
df['price'] = df['price'].str[3:] 
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(int)
df['price'].dtype
# Out:
# dtype('int32')

# %%
df['price'].tail()
# Out:
# 55    19099
# 56    11499
# 57    12999
# 58    15299
# 59     8255
# Name: price, dtype: int32

# %% [markdown]
# ## 4.Feature Extraction

# %%
import nltk
#nltk.download('punkt')
from nltk.tokenize import word_tokenize

# %% [markdown]
# Function to extract brand name

# %%
product_brands=['infinix','xiaomi','oppo','tecno','samsung','nokia','itel','ulefone','safaricom','vivo','realme']

def getbrand(name):
    name = name.lower()
    word_tokens= word_tokenize(name)
    brand = [char for char in word_tokens if char in product_brands]
    return ''.join(brand)

# %%
df['brand']=df['name'].apply(getbrand)

# %%
df
# Out:
#                                                  name  price      brand
# 0   Itel A58, 6.6",16 GB + 1GB, (Dual SIM) - Starr...   8150       itel
# 1   XIAOMI POCO M5 4GB + 128GB 6.58'' IPS LCD 50MP...  17999     xiaomi
# 2   Poco M4 Pro 6GB + 128GB 64MP 5000mAh 4G NFC Sm...  25799
# 3   Oppo A55, 6.51", 128GB + 4GB RAM (Dual SIM), 5...  23999       oppo
# 4   XIAOMI Redmi 10 6.5'' Inches 4+64GB 50MP Rear ...  19999     xiaomi
# 5   Samsung Galaxy A53 5G, 6.5", 128G + 8GB RAM (D...  45199    samsung
# 6   XIAOMI Redmi Note 11S, 6+128GB, 6.43", 1080p, ...  29499     xiaomi
# 7   Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000m...  11349    samsung
# 8   Ulefone S11, 6.1", 1GB RAM + 16GB (Dual SIM), ...   8999    ulefone
# 9   Samsung Galaxy A53 5G, 6.5", 128G + 8GB RAM (D...  45199    samsung
# 10  XIAOMI Redmi A1+, 6.52", 2GB+32GB, 8.0MP, 5000...  10899     xiaomi
# 11  Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000m...  11349    samsung
# 12  XIAOMI Redmi 10C 6.71'', 4GB+64GB, 50MP+2MP Ca...  16499     xiaomi
# 13  Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM...  12999      tecno
# 14  Ulefone Note 6, 6.1", 32GB + 1GB RAM (Dual SIM...   7599    ulefone
# 15      Itel P17, 5.5", 1GB + 16GB, (Dual SIM) - Blue   6839       itel
# 16  Infinix Hot 12 Play, 6.82", 64GB + 4GB RAM (Du...  15499    infinix
# 17  Oppo A16k, 6.52", 32GB + 3GB RAM (Dual SIM), 4...  14278       oppo
# 18  Tecno Spark 8C, 6.6", 64GB + 3GB RAM (Dual SIM...  13999      tecno
# 19  XIAOMI Redmi 10C 6.71'', 4GB+64GB, 50MP+2MP Ca...  16499     xiaomi
# 20  Tecno CAMON 18 Premier, 6.7", 256GB + 8GB RAM ...  29999      tecno
# 21  Nokia G21 – 6.5″ – 128GB + 4GB – Dual SIM Nord...  18900      nokia
# 22  Tecno Pop 6 Go, 6"display Screen Size,(32GB + ...   9599      tecno
# 23  Infinix Hot 12i, 6.6", 64GB + 2GB RAM (UP TO 4...  13499    infinix
# 24  Samsung Galaxy A23, 6.6″, 64GB + 4GB RAM (Dual...  22499    samsung
# 25  Ulefone Note 8, 5.5", 16GB + 2GB RAM, (Dual SI...   6499    ulefone
# 26  XIAOMI Redmi Note 10s, 6.43'', 6GB + 128GB, 64...  25199     xiaomi
# 27  XIAOMI Redmi Note 11, 6.43" , AMOLED, 4GB+64GB...  21499     xiaomi
# 28  Realme C11 2021, 6.5", 32GB RAM+ 2GB RAM (Dual...  10999     realme
# 29  Samsung Galaxy A33 5G, 6.4", 128GB + 6GB RAM (...  35599    samsung
# 30  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591  safaricom
# 31  Itel A33 Plus, 5.0", 16 GB + 1 GB RAM, (Dual S...   5919       itel
# 32  Vivo Y15s, 6.51'', 32 GB + 3 GB RAM (Dual SIM)...  12799       vivo
# 33  Tecno CAMON 18 Premier, 6.7", 256GB+ 8GB (Dual...  29499      tecno
# 34  Samsung Galaxy A03, 6.5", 32GB + 3GB RAM (Dual...  13199    samsung
# 35  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299    infinix
# 36  Infinix Hot 12i, 6.6", 64GB + 4GB RAM (Dual SI...  13499    infinix
# 37  Tecno Pop 6 6.1", 2GB RAM+32GB, 8MP, 4G (Dual ...   8819      tecno
# 38  XIAOMI Redmi 9A, 6.53", 2GB+32GB, 13.0MP, 5000...  11499     xiaomi
# 39  XIAOMI Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 500...  14799     xiaomi
# 40  XIAOMI Redmi 10 6.5'' Inches 4+128GB 50MP Rear...  18799     xiaomi
# 41  Oppo A16k, 6.52", 32GB + 3GB RAM (Dual SIM), 4...  14278       oppo
# 42  Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual...  19299    samsung
# 43  Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dua...  21699    samsung
# 44  Tecno Pova Neo, 6.8", 64GB+ 4GB (Dual SIM),4G ...  15999      tecno
# 45  Samsung Galaxy A13, 6.6", 64GB + 4GB RAM (Dual...  19299    samsung
# 46   Itel A14 Plus, 4", 8GB + 1GB RAM, 2500mAh - Blue   4443       itel
# 47  Samsung Galaxy A13, 6.6", 128GB + 4GB RAM (Dua...  21699    samsung
# 48  Nokia C1 2nd Edition, 5.45", 1GB +16GB - (DUAL...   7139      nokia
# 49  XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2M...  16299     xiaomi
# 50  Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000m...  11699    samsung
# 51  Samsung Galaxy A23, 6.6″, 64GB + 4GB RAM (Dual...  22499    samsung
# 52  Tecno CAMON 19, 6.8", 128GB+ 4GB (Dual SIM), (...  22499      tecno
# 53  Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual...  15299    samsung
# 54  XIAOMI Redmi 9C 6.53'', 4GB+128GB, 13MP+2MP+2M...  16499     xiaomi
# 55  XIAOMI Redmi 10C 6.71'', 4GB+128GB, 50MP+2MP C...  19099     xiaomi
# 56  XIAOMI Redmi 9A 6.53", 2GB RAM+32GB, 5000mAh, ...  11499     xiaomi
# 57  Tecno Spark 8C, 6.6", 64GB + 2GB RAM (Dual SIM...  12999      tecno
# 58  Samsung Galaxy A03, 6.5", 64GB + 4GB RAM (Dual...  15299    samsung
# 59  Itel A58 Lite, 6.3", 32GB + 2GB RAM (Dual SIM)...   8255       itel

# %% [markdown]
# Function to extract RAM

# %%
 df['name']=df['name'].str.replace('+',' ',regex=True)

# %%
ram_type=['1gb','2gb','3gb','4gb','2g','8gb']

def getram(name):
    name = name.lower()
    word_tokens= word_tokenize(name)
    ram = [char for char in word_tokens if char in ram_type]
    return ''.join(ram)
df['ram'] = df['name'].apply(getram)
df['ram'] = df['ram'].str[:-2]
df
# Out:
#                                                  name  price      brand   ram
# 0   Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150       itel     1
# 1   XIAOMI POCO M5 4GB   128GB 6.58'' IPS LCD 50MP...  17999     xiaomi     4
# 2   Poco M4 Pro 6GB   128GB 64MP 5000mAh 4G NFC Sm...  25799
# 3   Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999       oppo     4
# 4   XIAOMI Redmi 10 6.5'' Inches 4 64GB 50MP Rear ...  19999     xiaomi
# 5   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 6   XIAOMI Redmi Note 11S, 6 128GB, 6.43", 1080p, ...  29499     xiaomi
# 7   Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 8   Ulefone S11, 6.1", 1GB RAM   16GB (Dual SIM), ...   8999    ulefone     1
# 9   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 10  XIAOMI Redmi A1 , 6.52", 2GB 32GB, 8.0MP, 5000...  10899     xiaomi     2
# 11  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 12  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 13  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 14  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599    ulefone     1
# 15      Itel P17, 5.5", 1GB   16GB, (Dual SIM) - Blue   6839       itel     1
# 16  Infinix Hot 12 Play, 6.82", 64GB   4GB RAM (Du...  15499    infinix     4
# 17  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 18  Tecno Spark 8C, 6.6", 64GB   3GB RAM (Dual SIM...  13999      tecno     3
# 19  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 20  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999      tecno     8
# 21  Nokia G21 – 6.5″ – 128GB   4GB – Dual SIM Nord...  18900      nokia     4
# 22  Tecno Pop 6 Go, 6"display Screen Size,(32GB   ...   9599      tecno     2
# 23  Infinix Hot 12i, 6.6", 64GB   2GB RAM (UP TO 4...  13499    infinix  2gb4
# 24  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 25  Ulefone Note 8, 5.5", 16GB   2GB RAM, (Dual SI...   6499    ulefone     2
# 26  XIAOMI Redmi Note 10s, 6.43'', 6GB   128GB, 64...  25199     xiaomi
# 27  XIAOMI Redmi Note 11, 6.43" , AMOLED, 4GB 64GB...  21499     xiaomi     4
# 28  Realme C11 2021, 6.5", 32GB RAM  2GB RAM (Dual...  10999     realme     2
# 29  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599    samsung
# 30  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591  safaricom     1
# 31  Itel A33 Plus, 5.0", 16 GB   1 GB RAM, (Dual S...   5919       itel
# 32  Vivo Y15s, 6.51'', 32 GB   3 GB RAM (Dual SIM)...  12799       vivo
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499      tecno     8
# 34  Samsung Galaxy A03, 6.5", 32GB   3GB RAM (Dual...  13199    samsung     3
# 35  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299    infinix     2
# 36  Infinix Hot 12i, 6.6", 64GB   4GB RAM (Dual SI...  13499    infinix     4
# 37  Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819      tecno     2
# 38  XIAOMI Redmi 9A, 6.53", 2GB 32GB, 13.0MP, 5000...  11499     xiaomi     2
# 39  XIAOMI Redmi 10A, 6.53", 3GB 64GB, 13.0MP, 500...  14799     xiaomi     3
# 40  XIAOMI Redmi 10 6.5'' Inches 4 128GB 50MP Rear...  18799     xiaomi
# 41  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 42  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 43  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 44  Tecno Pova Neo, 6.8", 64GB  4GB (Dual SIM),4G ...  15999      tecno     4
# 45  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 46   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443       itel  8gb1
# 47  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 48  Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139      nokia     1
# 49  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16299     xiaomi     4
# 50  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11699    samsung
# 51  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 52  Tecno CAMON 19, 6.8", 128GB  4GB (Dual SIM), (...  22499      tecno     4
# 53  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 54  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16499     xiaomi     4
# 55  XIAOMI Redmi 10C 6.71'', 4GB 128GB, 50MP 2MP C...  19099     xiaomi     4
# 56  XIAOMI Redmi 9A 6.53", 2GB RAM 32GB, 5000mAh, ...  11499     xiaomi     2
# 57  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 58  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 59  Itel A58 Lite, 6.3", 32GB   2GB RAM (Dual SIM)...   8255       itel     2

# %%
#Function to extract storage
phone_storage=['8gb','16gb','32gb','64gb','128gb']

def getstorage(name):
    name = name.lower()
    word_tokens= word_tokenize(name)
    storage = [char for char in word_tokens if char in phone_storage]
    return ''.join(storage)
df['storage'] = df['name'].apply(getstorage)
df['storage'] = df['storage'].str[:-2]

df
# Out:
#                                                  name  price      brand   ram  \
# 0   Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150       itel     1
# 1   XIAOMI POCO M5 4GB   128GB 6.58'' IPS LCD 50MP...  17999     xiaomi     4
# 2   Poco M4 Pro 6GB   128GB 64MP 5000mAh 4G NFC Sm...  25799
# 3   Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999       oppo     4
# 4   XIAOMI Redmi 10 6.5'' Inches 4 64GB 50MP Rear ...  19999     xiaomi
# 5   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 6   XIAOMI Redmi Note 11S, 6 128GB, 6.43", 1080p, ...  29499     xiaomi
# 7   Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 8   Ulefone S11, 6.1", 1GB RAM   16GB (Dual SIM), ...   8999    ulefone     1
# 9   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 10  XIAOMI Redmi A1 , 6.52", 2GB 32GB, 8.0MP, 5000...  10899     xiaomi     2
# 11  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 12  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 13  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 14  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599    ulefone     1
# 15      Itel P17, 5.5", 1GB   16GB, (Dual SIM) - Blue   6839       itel     1
# 16  Infinix Hot 12 Play, 6.82", 64GB   4GB RAM (Du...  15499    infinix     4
# 17  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 18  Tecno Spark 8C, 6.6", 64GB   3GB RAM (Dual SIM...  13999      tecno     3
# 19  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 20  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999      tecno     8
# 21  Nokia G21 – 6.5″ – 128GB   4GB – Dual SIM Nord...  18900      nokia     4
# 22  Tecno Pop 6 Go, 6"display Screen Size,(32GB   ...   9599      tecno     2
# 23  Infinix Hot 12i, 6.6", 64GB   2GB RAM (UP TO 4...  13499    infinix  2gb4
# 24  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 25  Ulefone Note 8, 5.5", 16GB   2GB RAM, (Dual SI...   6499    ulefone     2
# 26  XIAOMI Redmi Note 10s, 6.43'', 6GB   128GB, 64...  25199     xiaomi
# 27  XIAOMI Redmi Note 11, 6.43" , AMOLED, 4GB 64GB...  21499     xiaomi     4
# 28  Realme C11 2021, 6.5", 32GB RAM  2GB RAM (Dual...  10999     realme     2
# 29  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599    samsung
# 30  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591  safaricom     1
# 31  Itel A33 Plus, 5.0", 16 GB   1 GB RAM, (Dual S...   5919       itel
# 32  Vivo Y15s, 6.51'', 32 GB   3 GB RAM (Dual SIM)...  12799       vivo
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499      tecno     8
# 34  Samsung Galaxy A03, 6.5", 32GB   3GB RAM (Dual...  13199    samsung     3
# 35  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299    infinix     2
# 36  Infinix Hot 12i, 6.6", 64GB   4GB RAM (Dual SI...  13499    infinix     4
# 37  Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819      tecno     2
# 38  XIAOMI Redmi 9A, 6.53", 2GB 32GB, 13.0MP, 5000...  11499     xiaomi     2
# 39  XIAOMI Redmi 10A, 6.53", 3GB 64GB, 13.0MP, 500...  14799     xiaomi     3
# 40  XIAOMI Redmi 10 6.5'' Inches 4 128GB 50MP Rear...  18799     xiaomi
# 41  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 42  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 43  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 44  Tecno Pova Neo, 6.8", 64GB  4GB (Dual SIM),4G ...  15999      tecno     4
# 45  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 46   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443       itel  8gb1
# 47  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 48  Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139      nokia     1
# 49  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16299     xiaomi     4
# 50  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11699    samsung
# 51  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 52  Tecno CAMON 19, 6.8", 128GB  4GB (Dual SIM), (...  22499      tecno     4
# 53  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 54  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16499     xiaomi     4
# 55  XIAOMI Redmi 10C 6.71'', 4GB 128GB, 50MP 2MP C...  19099     xiaomi     4
# 56  XIAOMI Redmi 9A 6.53", 2GB RAM 32GB, 5000mAh, ...  11499     xiaomi     2
# 57  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 58  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 59  Itel A58 Lite, 6.3", 32GB   2GB RAM (Dual SIM)...   8255       itel     2
#
#    storage
# 0
# 1      128
# 2      128
# 3      128
# 4       64
# 5        8
# 6      128
# 7       32
# 8       16
# 9        8
# 10      32
# 11      32
# 12      64
# 13      64
# 14      32
# 15      16
# 16      64
# 17      32
# 18      64
# 19      64
# 20       8
# 21     128
# 22      32
# 23      64
# 24      64
# 25      16
# 26     128
# 27      64
# 28      32
# 29     128
# 30      16
# 31
# 32
# 33       8
# 34      32
# 35      32
# 36      64
# 37      32
# 38      32
# 39      64
# 40     128
# 41      32
# 42      64
# 43     128
# 44      64
# 45      64
# 46       8
# 47     128
# 48      16
# 49     128
# 50      32
# 51      64
# 52     128
# 53      64
# 54     128
# 55     128
# 56      32
# 57      64
# 58      64
# 59      32

# %%
#to remove brackets
df['name']=df['name'].str.replace('()','')
df.sample(5)
# Out:
# C:\Users\kibe\AppData\Local\Temp\ipykernel_4900\4290031514.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['name']=df['name'].str.replace('()','')
#                                                  name  price    brand ram  \
# 29  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599  samsung
# 0   Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150     itel   1
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499    tecno   8
# 28  Realme C11 2021, 6.5", 32GB RAM  2GB RAM (Dual...  10999   realme   2
# 3   Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999     oppo   4
#
#    storage
# 29     128
# 0
# 33       8
# 28      32
# 3      128

# %%
sim_type=['dual']

def getsim(name):
    name = name.lower()
    word_tokens= word_tokenize(name)
    sim = [char for char in word_tokens if char in sim_type]
    return ''.join(sim)
df['sim'] = df['name'].apply(getsim)

df
# Out:
#                                                  name  price      brand   ram  \
# 0   Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150       itel     1
# 1   XIAOMI POCO M5 4GB   128GB 6.58'' IPS LCD 50MP...  17999     xiaomi     4
# 2   Poco M4 Pro 6GB   128GB 64MP 5000mAh 4G NFC Sm...  25799
# 3   Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999       oppo     4
# 4   XIAOMI Redmi 10 6.5'' Inches 4 64GB 50MP Rear ...  19999     xiaomi
# 5   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 6   XIAOMI Redmi Note 11S, 6 128GB, 6.43", 1080p, ...  29499     xiaomi
# 7   Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 8   Ulefone S11, 6.1", 1GB RAM   16GB (Dual SIM), ...   8999    ulefone     1
# 9   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 10  XIAOMI Redmi A1 , 6.52", 2GB 32GB, 8.0MP, 5000...  10899     xiaomi     2
# 11  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 12  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 13  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 14  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599    ulefone     1
# 15      Itel P17, 5.5", 1GB   16GB, (Dual SIM) - Blue   6839       itel     1
# 16  Infinix Hot 12 Play, 6.82", 64GB   4GB RAM (Du...  15499    infinix     4
# 17  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 18  Tecno Spark 8C, 6.6", 64GB   3GB RAM (Dual SIM...  13999      tecno     3
# 19  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 20  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999      tecno     8
# 21  Nokia G21 – 6.5″ – 128GB   4GB – Dual SIM Nord...  18900      nokia     4
# 22  Tecno Pop 6 Go, 6"display Screen Size,(32GB   ...   9599      tecno     2
# 23  Infinix Hot 12i, 6.6", 64GB   2GB RAM (UP TO 4...  13499    infinix  2gb4
# 24  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 25  Ulefone Note 8, 5.5", 16GB   2GB RAM, (Dual SI...   6499    ulefone     2
# 26  XIAOMI Redmi Note 10s, 6.43'', 6GB   128GB, 64...  25199     xiaomi
# 27  XIAOMI Redmi Note 11, 6.43" , AMOLED, 4GB 64GB...  21499     xiaomi     4
# 28  Realme C11 2021, 6.5", 32GB RAM  2GB RAM (Dual...  10999     realme     2
# 29  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599    samsung
# 30  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591  safaricom     1
# 31  Itel A33 Plus, 5.0", 16 GB   1 GB RAM, (Dual S...   5919       itel
# 32  Vivo Y15s, 6.51'', 32 GB   3 GB RAM (Dual SIM)...  12799       vivo
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499      tecno     8
# 34  Samsung Galaxy A03, 6.5", 32GB   3GB RAM (Dual...  13199    samsung     3
# 35  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299    infinix     2
# 36  Infinix Hot 12i, 6.6", 64GB   4GB RAM (Dual SI...  13499    infinix     4
# 37  Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819      tecno     2
# 38  XIAOMI Redmi 9A, 6.53", 2GB 32GB, 13.0MP, 5000...  11499     xiaomi     2
# 39  XIAOMI Redmi 10A, 6.53", 3GB 64GB, 13.0MP, 500...  14799     xiaomi     3
# 40  XIAOMI Redmi 10 6.5'' Inches 4 128GB 50MP Rear...  18799     xiaomi
# 41  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 42  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 43  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 44  Tecno Pova Neo, 6.8", 64GB  4GB (Dual SIM),4G ...  15999      tecno     4
# 45  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 46   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443       itel  8gb1
# 47  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 48  Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139      nokia     1
# 49  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16299     xiaomi     4
# 50  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11699    samsung
# 51  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 52  Tecno CAMON 19, 6.8", 128GB  4GB (Dual SIM), (...  22499      tecno     4
# 53  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 54  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16499     xiaomi     4
# 55  XIAOMI Redmi 10C 6.71'', 4GB 128GB, 50MP 2MP C...  19099     xiaomi     4
# 56  XIAOMI Redmi 9A 6.53", 2GB RAM 32GB, 5000mAh, ...  11499     xiaomi     2
# 57  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 58  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 59  Itel A58 Lite, 6.3", 32GB   2GB RAM (Dual SIM)...   8255       itel     2
#
#    storage   sim
# 0           dual
# 1      128
# 2      128
# 3      128  dual
# 4       64
# 5        8  dual
# 6      128
# 7       32  dual
# 8       16  dual
# 9        8  dual
# 10      32  dual
# 11      32  dual
# 12      64  dual
# 13      64  dual
# 14      32  dual
# 15      16  dual
# 16      64  dual
# 17      32  dual
# 18      64  dual
# 19      64  dual
# 20       8  dual
# 21     128  dual
# 22      32  dual
# 23      64  dual
# 24      64  dual
# 25      16  dual
# 26     128  dual
# 27      64
# 28      32  dual
# 29     128  dual
# 30      16
# 31          dual
# 32          dual
# 33       8  dual
# 34      32  dual
# 35      32
# 36      64  dual
# 37      32  dual
# 38      32  dual
# 39      64  dual
# 40     128
# 41      32  dual
# 42      64  dual
# 43     128  dual
# 44      64  dual
# 45      64  dual
# 46       8
# 47     128  dual
# 48      16  dual
# 49     128  dual
# 50      32  dual
# 51      64  dual
# 52     128  dual
# 53      64  dual
# 54     128  dual
# 55     128  dual
# 56      32  dual
# 57      64  dual
# 58      64  dual
# 59      32  dual

# %%
df.isnull()
# Out:
#      name  price  brand    ram  storage    sim
# 0   False  False  False  False    False  False
# 1   False  False  False  False    False  False
# 2   False  False  False  False    False  False
# 3   False  False  False  False    False  False
# 4   False  False  False  False    False  False
# 5   False  False  False  False    False  False
# 6   False  False  False  False    False  False
# 7   False  False  False  False    False  False
# 8   False  False  False  False    False  False
# 9   False  False  False  False    False  False
# 10  False  False  False  False    False  False
# 11  False  False  False  False    False  False
# 12  False  False  False  False    False  False
# 13  False  False  False  False    False  False
# 14  False  False  False  False    False  False
# 15  False  False  False  False    False  False
# 16  False  False  False  False    False  False
# 17  False  False  False  False    False  False
# 18  False  False  False  False    False  False
# 19  False  False  False  False    False  False
# 20  False  False  False  False    False  False
# 21  False  False  False  False    False  False
# 22  False  False  False  False    False  False
# 23  False  False  False  False    False  False
# 24  False  False  False  False    False  False
# 25  False  False  False  False    False  False
# 26  False  False  False  False    False  False
# 27  False  False  False  False    False  False
# 28  False  False  False  False    False  False
# 29  False  False  False  False    False  False
# 30  False  False  False  False    False  False
# 31  False  False  False  False    False  False
# 32  False  False  False  False    False  False
# 33  False  False  False  False    False  False
# 34  False  False  False  False    False  False
# 35  False  False  False  False    False  False
# 36  False  False  False  False    False  False
# 37  False  False  False  False    False  False
# 38  False  False  False  False    False  False
# 39  False  False  False  False    False  False
# 40  False  False  False  False    False  False
# 41  False  False  False  False    False  False
# 42  False  False  False  False    False  False
# 43  False  False  False  False    False  False
# 44  False  False  False  False    False  False
# 45  False  False  False  False    False  False
# 46  False  False  False  False    False  False
# 47  False  False  False  False    False  False
# 48  False  False  False  False    False  False
# 49  False  False  False  False    False  False
# 50  False  False  False  False    False  False
# 51  False  False  False  False    False  False
# 52  False  False  False  False    False  False
# 53  False  False  False  False    False  False
# 54  False  False  False  False    False  False
# 55  False  False  False  False    False  False
# 56  False  False  False  False    False  False
# 57  False  False  False  False    False  False
# 58  False  False  False  False    False  False
# 59  False  False  False  False    False  False

# %% [markdown]
# ## Data Visualization

# %%
#Distribution of prices in our dataset
df['price'].hist(figsize=(8,5))
plt.title('Distribution of Jumia phone prices', fontsize=18)

plt.show()

# %% [markdown]
# Most of the devices in our data frame lie between ksh10,000 and ksh15,500

# %%
#most expensive mobile phones in our dataset
most_expensive_phones = df[['name', 'price']].sort_values('price', ascending=False).head(10)
most_expensive_phones = most_expensive_phones.reset_index(drop=True)
most_expensive_phones
# Out:
#                                                 name  price
# 0  Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199
# 1  Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199
# 2  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599
# 3  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999
# 4  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499
# 5  XIAOMI Redmi Note 11S, 6 128GB, 6.43", 1080p, ...  29499
# 6  Poco M4 Pro 6GB   128GB 64MP 5000mAh 4G NFC Sm...  25799
# 7  XIAOMI Redmi Note 10s, 6.43'', 6GB   128GB, 64...  25199
# 8  Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999
# 9  Tecno CAMON 19, 6.8", 128GB  4GB (Dual SIM), (...  22499

# %%
#least expensive 
least_expensive_phones = df[['name', 'price']].sort_values('price', ascending=True).head(10)
least_expensive_phones = least_expensive_phones.reset_index(drop=True)
least_expensive_phones
# Out:
#                                                 name  price
# 0   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443
# 1  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591
# 2  Itel A33 Plus, 5.0", 16 GB   1 GB RAM, (Dual S...   5919
# 3  Ulefone Note 8, 5.5", 16GB   2GB RAM, (Dual SI...   6499
# 4      Itel P17, 5.5", 1GB   16GB, (Dual SIM) - Blue   6839
# 5  Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139
# 6  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599
# 7  Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150
# 8  Itel A58 Lite, 6.3", 32GB   2GB RAM (Dual SIM)...   8255
# 9  Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819

# %%
sim_type_distribution = df['sim'].value_counts()
sim_type_distribution
avg_sim_distr= df.groupby('brand')(sim_type_distribution).mean().to_frame()
avg_sim_distr.sort_values('', ascending=False, inplace=True)
#avg_brand_pricef.groupby('brand')['price'].mean().to_frame()
#avg_brand_price.sort_values('price', ascending=False, inplace=True)
avg_sim_distr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 3>()
#       1 sim_type_distribution = df['sim'].value_counts()
#       2 sim_type_distribution
# ----> 3 avg_sim_distr= df.groupby('brand')(sim_type_distribution).mean().to_frame()
#       4 avg_sim_distr.sort_values('', ascending=False, inplace=True)
#       5 #avg_brand_pricef.groupby('brand')['price'].mean().to_frame()
#       6 #avg_brand_price.sort_values('price', ascending=False, inplace=True)
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
#distribution of brands
brand_distribution = df['brand'].value_counts()

plt.figure(figsize = (9,6))
brand_distribution.plot.bar(color='dodgerblue')
plt.title('Distribution of brands', fontsize=18)
plt.xlabel('brand', fontsize=15)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# The most available brand is Xiaomi and the least available is Vivo

# %%
#average brand price
avg_brand_price = df.groupby('brand')['price'].mean().to_frame()
avg_brand_price.sort_values('price', ascending=False, inplace=True)
avg_brand_price

plt.figure(figsize = (10,6))
avg_brand_price.plot.bar(color='dodgerblue')
plt.title('Average price by brand', fontsize=18)
plt.xlabel('brand', fontsize=14)
plt.ylabel('price', fontsize=14)
plt.xticks(rotation=45)
plt.ticklabel_format(style = 'plain', axis='y')
plt.show()

# %% [markdown]
# The overall most expensive phone brand is samsung and the least is Safaricom

# %%
avg_ram_price = df.groupby('ram')['price'].mean().to_frame()
avg_ram_price.sort_values('price', ascending=False, inplace=True)
avg_ram_price.drop('', inplace=True)
avg_ram_price
# Out:
#              price
# ram
# 8     37474.000000
# 4     18684.761905
# 3     14110.600000
# 2gb4  13499.000000
# 2     10396.818182
# 1      7219.500000
# 8gb1   4443.000000

# %%
br = df.groupby('brand')
br.first()
# Out:
#                                                       name  price ram storage  \
# brand
# infinix  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299   2      32
# itel      Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443   1       8
# nokia    Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139   1      16
# oppo     Oppo A83 64GB   4GB RAM - 4G LTE Dual SIM -  5...   9990   4      64
# samsung  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299   4      64
# tecno    Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819   2      32
# ulefone  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599   1      32
# xiaomi   XIAOMI Redmi 9A, 6.53", 2GB 32GB, 13.0MP, 5000...  11499   2      32
#
#           sim
# brand
# infinix
# itel
# nokia    dual
# oppo     dual
# samsung  dual
# tecno    dual
# ulefone  dual
# xiaomi   dual

# %%
br.get_group('infinix')
# Out:
#                                                  name  price    brand ram  \
# 0   Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299  infinix   2
# 6   Infinix Smart 6, 6.6", 32GB   2GB RAM (Dual SI...  10695  infinix   2
# 25  Infinix HOT 12i, 6.6''{ 64GB 2GB Expandable To...  12995  infinix   2
# 31  Infinix Smart 6, 6.6", 32GB   2GB RAM (Dual SI...  11100  infinix   2
# 36  Infinix Smart 6, 6.6", 2GB RAM, 32GB, Android ...  10695  infinix   2
#
#    storage   sim
# 0       32
# 6       32  dual
# 25      64  dual
# 31      32  dual
# 36      32

# %%
import pandasql as ps

# %%
#most  storage 
print(df[df.storage == df.storage.max()])
# Out:
#                                                  name  price    brand   ram  \
# 5   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199  samsung     8
# 9   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199  samsung     8
# 20  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999    tecno     8
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499    tecno     8
# 46   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443     itel  8gb1
#
#    storage   sim
# 5        8  dual
# 9        8  dual
# 20       8  dual
# 33       8  dual
# 46       8

# %%
def best(df):
    df[df.storage == df.storage.max()]
    df[df.ram == df.ram.max()]
    #df=dataframe
    return df
#df=dataframe
df_best=best(df)
df_best
# Out:
#                                                  name  price      brand   ram  \
# 0   Itel A58, 6.6",16 GB   1GB, (Dual SIM) - Starr...   8150       itel     1
# 1   XIAOMI POCO M5 4GB   128GB 6.58'' IPS LCD 50MP...  17999     xiaomi     4
# 2   Poco M4 Pro 6GB   128GB 64MP 5000mAh 4G NFC Sm...  25799
# 3   Oppo A55, 6.51", 128GB   4GB RAM (Dual SIM), 5...  23999       oppo     4
# 4   XIAOMI Redmi 10 6.5'' Inches 4 64GB 50MP Rear ...  19999     xiaomi
# 5   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 6   XIAOMI Redmi Note 11S, 6 128GB, 6.43", 1080p, ...  29499     xiaomi
# 7   Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 8   Ulefone S11, 6.1", 1GB RAM   16GB (Dual SIM), ...   8999    ulefone     1
# 9   Samsung Galaxy A53 5G, 6.5", 128G   8GB RAM (D...  45199    samsung     8
# 10  XIAOMI Redmi A1 , 6.52", 2GB 32GB, 8.0MP, 5000...  10899     xiaomi     2
# 11  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11349    samsung
# 12  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 13  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 14  Ulefone Note 6, 6.1", 32GB   1GB RAM (Dual SIM...   7599    ulefone     1
# 15      Itel P17, 5.5", 1GB   16GB, (Dual SIM) - Blue   6839       itel     1
# 16  Infinix Hot 12 Play, 6.82", 64GB   4GB RAM (Du...  15499    infinix     4
# 17  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 18  Tecno Spark 8C, 6.6", 64GB   3GB RAM (Dual SIM...  13999      tecno     3
# 19  XIAOMI Redmi 10C 6.71'', 4GB 64GB, 50MP 2MP Ca...  16499     xiaomi     4
# 20  Tecno CAMON 18 Premier, 6.7", 256GB   8GB RAM ...  29999      tecno     8
# 21  Nokia G21 – 6.5″ – 128GB   4GB – Dual SIM Nord...  18900      nokia     4
# 22  Tecno Pop 6 Go, 6"display Screen Size,(32GB   ...   9599      tecno     2
# 23  Infinix Hot 12i, 6.6", 64GB   2GB RAM (UP TO 4...  13499    infinix  2gb4
# 24  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 25  Ulefone Note 8, 5.5", 16GB   2GB RAM, (Dual SI...   6499    ulefone     2
# 26  XIAOMI Redmi Note 10s, 6.43'', 6GB   128GB, 64...  25199     xiaomi
# 27  XIAOMI Redmi Note 11, 6.43" , AMOLED, 4GB 64GB...  21499     xiaomi     4
# 28  Realme C11 2021, 6.5", 32GB RAM  2GB RAM (Dual...  10999     realme     2
# 29  Samsung Galaxy A33 5G, 6.4", 128GB   6GB RAM (...  35599    samsung
# 30  Safaricom Neon Ray 2, 5.0" , Android 10, 1GB R...   4591  safaricom     1
# 31  Itel A33 Plus, 5.0", 16 GB   1 GB RAM, (Dual S...   5919       itel
# 32  Vivo Y15s, 6.51'', 32 GB   3 GB RAM (Dual SIM)...  12799       vivo
# 33  Tecno CAMON 18 Premier, 6.7", 256GB  8GB (Dual...  29499      tecno     8
# 34  Samsung Galaxy A03, 6.5", 32GB   3GB RAM (Dual...  13199    samsung     3
# 35  Infinix Smart 6, 6.6", 2GB RAM, 32GB, 5000mAh,...  10299    infinix     2
# 36  Infinix Hot 12i, 6.6", 64GB   4GB RAM (Dual SI...  13499    infinix     4
# 37  Tecno Pop 6 6.1", 2GB RAM 32GB, 8MP, 4G (Dual ...   8819      tecno     2
# 38  XIAOMI Redmi 9A, 6.53", 2GB 32GB, 13.0MP, 5000...  11499     xiaomi     2
# 39  XIAOMI Redmi 10A, 6.53", 3GB 64GB, 13.0MP, 500...  14799     xiaomi     3
# 40  XIAOMI Redmi 10 6.5'' Inches 4 128GB 50MP Rear...  18799     xiaomi
# 41  Oppo A16k, 6.52", 32GB   3GB RAM (Dual SIM), 4...  14278       oppo     3
# 42  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 43  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 44  Tecno Pova Neo, 6.8", 64GB  4GB (Dual SIM),4G ...  15999      tecno     4
# 45  Samsung Galaxy A13, 6.6", 64GB   4GB RAM (Dual...  19299    samsung     4
# 46   Itel A14 Plus, 4", 8GB   1GB RAM, 2500mAh - Blue   4443       itel  8gb1
# 47  Samsung Galaxy A13, 6.6", 128GB   4GB RAM (Dua...  21699    samsung     4
# 48  Nokia C1 2nd Edition, 5.45", 1GB  16GB - (DUAL...   7139      nokia     1
# 49  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16299     xiaomi     4
# 50  Samsung Galaxy A03 Core, 6.5" 32GB   2G, 5000m...  11699    samsung
# 51  Samsung Galaxy A23, 6.6″, 64GB   4GB RAM (Dual...  22499    samsung     4
# 52  Tecno CAMON 19, 6.8", 128GB  4GB (Dual SIM), (...  22499      tecno     4
# 53  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 54  XIAOMI Redmi 9C 6.53'', 4GB 128GB, 13MP 2MP 2M...  16499     xiaomi     4
# 55  XIAOMI Redmi 10C 6.71'', 4GB 128GB, 50MP 2MP C...  19099     xiaomi     4
# 56  XIAOMI Redmi 9A 6.53", 2GB RAM 32GB, 5000mAh, ...  11499     xiaomi     2
# 57  Tecno Spark 8C, 6.6", 64GB   2GB RAM (Dual SIM...  12999      tecno     2
# 58  Samsung Galaxy A03, 6.5", 64GB   4GB RAM (Dual...  15299    samsung     4
# 59  Itel A58 Lite, 6.3", 32GB   2GB RAM (Dual SIM)...   8255       itel     2
#
#    storage   sim
# 0           dual
# 1      128
# 2      128
# 3      128  dual
# 4       64
# 5        8  dual
# 6      128
# 7       32  dual
# 8       16  dual
# 9        8  dual
# 10      32  dual
# 11      32  dual
# 12      64  dual
# 13      64  dual
# 14      32  dual
# 15      16  dual
# 16      64  dual
# 17      32  dual
# 18      64  dual
# 19      64  dual
# 20       8  dual
# 21     128  dual
# 22      32  dual
# 23      64  dual
# 24      64  dual
# 25      16  dual
# 26     128  dual
# 27      64
# 28      32  dual
# 29     128  dual
# 30      16
# 31          dual
# 32          dual
# 33       8  dual
# 34      32  dual
# 35      32
# 36      64  dual
# 37      32  dual
# 38      32  dual
# 39      64  dual
# 40     128
# 41      32  dual
# 42      64  dual
# 43     128  dual
# 44      64  dual
# 45      64  dual
# 46       8
# 47     128  dual
# 48      16  dual
# 49     128  dual
# 50      32  dual
# 51      64  dual
# 52     128  dual
# 53      64  dual
# 54     128  dual
# 55     128  dual
# 56      32  dual
# 57      64  dual
# 58      64  dual
# 59      32  dual
